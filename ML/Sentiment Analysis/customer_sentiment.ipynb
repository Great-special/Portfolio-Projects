# %%
from textblob import TextBlob

# Example customer reviews
reviews = [
    "The product is amazing! I love it.",
    "Terrible experience, I will never buy this again.",
    "It's okay, not the best but not the worst.",
    "Absolutely fantastic service and quality!",
    "The product broke after one use. Very disappointed."
]

# Analyze sentiment
for review in reviews:
    analysis = TextBlob(review)
    print(analysis.sentiment.polarity)
    sentiment = "Positive" if analysis.sentiment.polarity > 0 else "Negative" if analysis.sentiment.polarity < 0 else "Neutral"
    print(f"Review: {review}\nSentiment: {sentiment}\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from textblob import TextBlob
#       3 # Example customer reviews
#       4 reviews = [
#       5     "The product is amazing! I love it.",
#       6     "Terrible experience, I will never buy this again.",
#    (...)
#       9     "The product broke after one use. Very disappointed."
#      10 ]
#
# ModuleNotFoundError: No module named 'textblob'
